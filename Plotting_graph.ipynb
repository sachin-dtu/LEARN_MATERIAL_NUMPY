# %% [markdown]
# <a href="https://colab.research.google.com/github/sachin-dtu/LEARN_MATERIAL_NUMPY/blob/Pandas_LM/Plotting_graph.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # CONTENTS
#
# ## [Line plot with basic introduction ](https://colab.research.google.com/drive/1lwtNx2Cdl3hEBlHAGQ5g40nuryblcf8R#scrollTo=sFQ07w0ywpEP)
# ## [Scatter Plot](https://colab.research.google.com/drive/1lwtNx2Cdl3hEBlHAGQ5g40nuryblcf8R#scrollTo=xNiQVWCywiCP)
# 1. [Basic dotted types](https://colab.research.google.com/drive/1lwtNx2Cdl3hEBlHAGQ5g40nuryblcf8R#scrollTo=HfDfRNPiK04P)
# 2. [Circle with population density with size](https://colab.research.google.com/drive/1lwtNx2Cdl3hEBlHAGQ5g40nuryblcf8R#scrollTo=36BA-BDxK7nR)
# 3. [Triangular part of scatter](https://colab.research.google.com/drive/1lwtNx2Cdl3hEBlHAGQ5g40nuryblcf8R#scrollTo=f8YZ69R5LPrm)
# 4. [Naming on scatter pointing](https://colab.research.google.com/drive/1lwtNx2Cdl3hEBlHAGQ5g40nuryblcf8R#scrollTo=a_eQQNPHLYmE)
# ## [Pie graphs](https://colab.research.google.com/drive/1lwtNx2Cdl3hEBlHAGQ5g40nuryblcf8R#scrollTo=mqqEIZrIwaOO)
# 1. [Normal pie graph](https://colab.research.google.com/drive/1lwtNx2Cdl3hEBlHAGQ5g40nuryblcf8R#scrollTo=0p_ffYhNIhLW)
# 2. [Pie graph split with labels and color](https://colab.research.google.com/drive/1lwtNx2Cdl3hEBlHAGQ5g40nuryblcf8R#scrollTo=ljfrJqPVJDqw)
# ## [Histogram](https://colab.research.google.com/drive/1lwtNx2Cdl3hEBlHAGQ5g40nuryblcf8R#scrollTo=MKJJ3A2Kra-O)
# 1. [Bin, Edgecolor](https://colab.research.google.com/drive/1lwtNx2Cdl3hEBlHAGQ5g40nuryblcf8R#scrollTo=RAWHE_D_L13S)
# 2. [Problem Statement for practice](https://colab.research.google.com/drive/1lwtNx2Cdl3hEBlHAGQ5g40nuryblcf8R#scrollTo=9jI2ofn3lxyA)
# ## [BarGraph](https://colab.research.google.com/drive/1lwtNx2Cdl3hEBlHAGQ5g40nuryblcf8R#scrollTo=X3RCSNu5Fv8B)
# 1. [For rotation of labels on x-axis](https://colab.research.google.com/drive/1lwtNx2Cdl3hEBlHAGQ5g40nuryblcf8R#scrollTo=S5XTUIooIM9c)

# %% [markdown]
# # Line plot with basic intro

# %%
import matplotlib.pyplot as plt
x = [1,2,3]
y = [2,4,6]
plt.scatter(x,y)
plt.show()

# %%
x = [1,2,3]
y = [2,4,6]
plt.plot(x,y) # this will basically store as plot line data
plt.show()

# %%
x = [1,2,3]
y = [2,4,6]
plt.scatter(x,y) # this will basically store dot in plot data
plt.plot(x,y) # this will basically store as plot line data
plt.show()

# %%
x = [1,2,3]
y = [2,4,6]
x2 = [3,4,5]
y2 = [2,4,6]

plt.plot(x2,y2) # this will basically store as plot line data
plt.plot(x,y) # this will basically store as plot line data
plt.show()

# %%
x = [1,2,3]
y = [2,4,6]
x2 = [3,4,5]
y2 = [2,4,6]
#  (x2,y2,"y") here "y" or other eg "Yellow" with full name will be responsible for the colour of line in graph
plt.plot(x2,y2,"y") # this will basically store as plot line data
plt.plot(x,y) # this will basically store as plot line data
plt.show()

# %%
x = [1,2,3]
y = [2,4,6]
x2 = [3,4,5]
y2 = [2,4,6]
#  (x2,y2,"y") here "y" or other eg "Yellow" with full name will be responsible for the colour of line in graph
# "yo" as you can see dot will form
plt.plot(x2,y2,"yo") # this will basically store as plot line data
plt.plot(x,y) # this will basically store as plot line data
plt.show()

# %%
x = [1,2,3]
y = [2,4,6]
x2 = [3,4,5]
y2 = [2,4,6]
#  (x2,y2,"y") here "y" or other eg "Yellow" with full name will be responsible for the colour of line in graph
# "yo" as you can see dot will form
# * "b--" doted line form
# * "bp" for pointed type
# * "b-." for line dot
# * ""
plt.plot(x2,y2,"b--") # this will basically store as plot line data
plt.plot(x,y) # this will basically store as plot line data
plt.show()

# %%
# plot function x^3
import numpy as np
x = np.array([1,2,3,4])
y = x**3
plt.plot(x,y)

# %%
# plot function x^3
import numpy as np
x = np.arange(-100,100,0.1)
y = x**3
plt.plot(x,y)
plt.show()

# %%
a = [3,4,5]
plt.plot(a)
plt.show()

# %%
# plot function x^3
import matplotlib.pyplot as plt
import numpy as np
x = np.arange(0,5,0.1)
y = x**3
plt.plot(x,y,color ="red",marker="p")
plt.show()

# %%
# plot function x^3
import matplotlib.pyplot as plt
import numpy as np
x = np.arange(0,5,0.1)
y = x**3
plt.plot(x,y,color ="red",marker="*",linewidth="0.5")
plt.show()

# %%
import pandas as pd   
iris=pd.read_csv("https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data")
iris.drop(0,inplace = True)
iris.drop(2,inplace = True)
print(iris)
# Out:
#      5.1  3.5  1.4  0.2     Iris-setosa
# 1    4.7  3.2  1.3  0.2     Iris-setosa
# 3    5.0  3.6  1.4  0.2     Iris-setosa
# 4    5.4  3.9  1.7  0.4     Iris-setosa
# 5    4.6  3.4  1.4  0.3     Iris-setosa
# 6    5.0  3.4  1.5  0.2     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 144  6.7  3.0  5.2  2.3  Iris-virginica
# 145  6.3  2.5  5.0  1.9  Iris-virginica
# 146  6.5  3.0  5.2  2.0  Iris-virginica
# 147  6.2  3.4  5.4  2.3  Iris-virginica
# 148  5.9  3.0  5.1  1.8  Iris-virginica
#
# [147 rows x 5 columns]

# %%
import pandas as pd   
iris=pd.read_csv("https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data")
print(iris)
# Out:
#      5.1  3.5  1.4  0.2     Iris-setosa
# 0    4.9  3.0  1.4  0.2     Iris-setosa
# 1    4.7  3.2  1.3  0.2     Iris-setosa
# 2    4.6  3.1  1.5  0.2     Iris-setosa
# 3    5.0  3.6  1.4  0.2     Iris-setosa
# 4    5.4  3.9  1.7  0.4     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 144  6.7  3.0  5.2  2.3  Iris-virginica
# 145  6.3  2.5  5.0  1.9  Iris-virginica
# 146  6.5  3.0  5.2  2.0  Iris-virginica
# 147  6.2  3.4  5.4  2.3  Iris-virginica
# 148  5.9  3.0  5.1  1.8  Iris-virginica
#
# [149 rows x 5 columns]

# %%
import pandas as pd   
iris=pd.read_csv("https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data")
print(iris.tail(3))
# Out:
#      5.1  3.5  1.4  0.2     Iris-setosa
# 146  6.5  3.0  5.2  2.0  Iris-virginica
# 147  6.2  3.4  5.4  2.3  Iris-virginica
# 148  5.9  3.0  5.1  1.8  Iris-virginica

# %%
iris.iloc[-3:]
# Out:
#      5.1  3.5  1.4  0.2     Iris-setosa
# 146  6.5  3.0  5.2  2.0  Iris-virginica
# 147  6.2  3.4  5.4  2.3  Iris-virginica
# 148  5.9  3.0  5.1  1.8  Iris-virginica

# %%
import numpy as np
import matplotlib.pyplot as plt
x1 =[0,1,2,3,4,5,6,7,9,10]
x2 = np.arange(0,40,2)
y1=[1,2,5,10,17,26,37,50,82,101]
y2 = 2*x2
plt.plot(x1,y1)
plt.plot(x2,y2)
plt.show()

# %%
i=1
while i<5:
    if i == 3:
        break
    print(i, end=" ")
    i = i + 1
else:
    print("Else is also printed")
# Out:
# 1 2

# %% [markdown]
# # Scatter Plot

# %% [markdown]
# ## Basic dotted types

# %%
import numpy as np
import matplotlib.pyplot as plt
year = [2012,2013,2014,2015,2016,2017]
salary = [12,13,14,17,19,20]
population = [100,120,180,250,300,370]
plt.scatter(year,salary)
plt.show()

# %% [markdown]
# ## Circle with population density with size

# %%
import numpy as np
c = np.arange(len(year))
plt.scatter(year,salary,s=population,c=c,alpha=0.5,edgecolor ="black")
plt.show()

# %% [markdown]
# ## Triangular part of scatter

# %%
import numpy as np
c = np.arange(len(year))
plt.scatter(year,salary,s=population,c=c,alpha=0.5,edgecolor ="black",marker="^")
plt.show()

# %% [markdown]
# ## Naming on scatter pointing

# %%
import numpy as np
c = np.arange(len(year))
plt.scatter(year,salary,s=population,c=c,alpha=0.5,edgecolor ="black",marker="^")
plt.text(year[0]+0.1,salary[0]+0.1,population[0])
plt.show()

# %%
import matplotlib.pyplot as plt
employees=[61,71,79,91,93,89,90,94,99,128,118,114,124,131]
year=[2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018]
revenue=[39.79,44.28,51.12,60.42,58.44,62.48,69.94,73.72,77.85,86.83,93.58,85.32,89.95,110.36]
plt.scatter(year,revenue,s=employees)
plt.show()
print('2008','60.42','91')
print('2015','93.58','118')
# Out:
# 2008 60.42 91
# 2015 93.58 118

# %% [markdown]
# # Pie graphs

# %% [markdown]
# ###   Normal pie graph

# %%
# pie graphs
import matplotlib.pyplot as plt
sizes = [3,4,6,2]
plt.pie(sizes)
plt.axis("equal")
plt.show()

# %% [markdown]
# ### Pie graph split with labels and color

# %%
# pie graphs
import matplotlib.pyplot as plt
labels  = ["A","B","C","D"]
sizes = [3,4,6,2]
explode = [0.1,0,0,0]
colors = ["blue","purple","red","pink"]
plt.title("Split among classes")
plt.pie(sizes,colors = colors,labels = labels,autopct="%0.1f",explode=explode)
plt.axis("equal")
plt.show()

# %%
company=['HP','Dell','Lenovo','Asus','Apple','Acer']
sold=[20000,43000,15000,17000,22000,13000]
import matplotlib.pyplot as plt
sold=[20000,43000,15000,17000,22000,13000]
company=['HP','Dell','Lenovo','Asus','Apple','Acer']
plt.title("%Age distribution for the year 2018")
plt.pie(sold,labels = company,autopct="%0.1f")
plt.axis("equal")
plt.show()
hello = [15.4,33.1,11.5,13.1,16.9,10.0,15.4]
n = len(company)
for i in range(n):
    print(company[i],hello[i])
# Out:
# HP 15.4
# Dell 33.1
# Lenovo 11.5
# Asus 13.1
# Apple 16.9
# Acer 10.0

# %% [markdown]
# # Histogram

# %%
import matplotlib.pyplot as plt
a = [1,2,3,4,1,3,2,1,1]
plt.hist(a,edgecolor = "black")
plt.xticks([1,2,3,4,5])
plt.axis([0,10,0,10])
plt.show()

# %% [markdown]
# ## Bin,edgecolor
# * Bin (this basically fill and resposible to showing portion)

# %%
import matplotlib.pyplot as plt
height=[189,185,195,149,189,147,154,174,169,195,159,192,155,191,153,157,140,144,172,157]
## Weight
weight=[87,110,104,61,104,92,111,90,103,81,80,101,51,79,107,110,129,145,139,110]
plt.hist(height,bins = 5,edgecolor = "black")
plt.show()
plt.hist(weight,edgecolor = "pink")
plt.show()

# %%
import matplotlib.pyplot as plt
height=[189,185,195,149,189,147,154,174,169,195,159,192,155,191,153,157,140,144,172,157]
## Weight
weight=[87,110,104,61,104,92,111,90,103,81,80,101,51,79,107,110,129,145,139,110]
plt.hist(height,bins = 5,edgecolor = "black")
plt.show()
plt.hist(weight,bins=5,edgecolor = "pink")
plt.show()

# %% [markdown]
# ## Problem Statment for practice
# ## Plot Job_Year
#
# ### Given File:
# * amazon_jobs_dataset.csv
# * It is a dataset including information on amazon job opening around the world from June 2011 to March 2018. This dataset is collected using Selenium and BeautifulSoup by scraping all of the jobs for Amazon job site.
# ### Problem Statement :
# * Plot the line graph between no. of Job postings with respect to year.
# * Print the year and the number of job posting as integer value.
# * Note: Year should be in ascending order.
# ### Output Format :
# * year1   job_posting1
# * year2   job_posting2
# * . . .
# * . . .
# * . . .

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import csv

import collections
with open('/content/amazon_jobs_dataset (1).csv', encoding ='UTF-8') as file_obj:
    file_data = csv.DictReader(file_obj, skipinitialspace=True)

    dct = {}
    for row in file_data:
        date = row['Posting_date'].split()
        key = date[2]
        if key in dct:
            dct[key] += 1
        else:
            dct[key] = 1
            
    ord_dct = collections.OrderedDict(sorted(dct.items()))                                  
    plt.plot(list(ord_dct.keys()),list(ord_dct.values()))
    plt.xlabel("Year")
    plt.ylabel("Jobs")
    plt.title('Year vs Job_Openings')
    plt.show()
    
    for i in ord_dct.keys():
        print(i,end=" ")
        print(ord_dct[i])
# Out:
# 2011 2
# 2012 7
# 2013 3
# 2014 5
# 2015 29
# 2016 123
# 2017 1614
# 2018 1710

# %% [markdown]
# # BarGraph

# %%
year = [2012,2013,2014,2015,2016,2017]
salary = [12,13,14,17,19,20]
population = [100,120,180,250,300,370]

# %%
import matplotlib.pyplot as plt
plt.bar(year,population)
plt.show()

# %%
plt.bar(year,population,width=0.2)
plt.show()

# %%
plt.bar(year,population,width=1)
plt.show()

# %%
year = ["year - 2012","year-2013","year- 2014","year- 2015","year- 2016","year- 2017"]
salary = [12,13,14,17,19,20]
population = [100,120,180,250,300,370]

# %% [markdown]
# ## For rotation of labels on x axis

# %%
import matplotlib.pyplot as plt
plt.bar(year,population)
plt.show()

# %%
import matplotlib.pyplot as plt
plt.bar(year,population,width =0.6)
plt.xticks(rotation=60)
plt.show()
